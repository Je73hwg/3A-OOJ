# %% [markdown]
# <a href="https://colab.research.google.com/github/Je73hwg/3A-OOJ/blob/main/8*8nQUeen_hillClimbing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = 8  # Number of queens and the size of the board (8*8)

# Cost function: counts the number of attacking pairs of queens.
def calculateCost(state):
    attacking_pairs = 0
    for i in range(N):
        for j in range(i + 1, N):
            if state[i] == state[j] or abs(state[i] - state[j]) == abs(i - j):
                attacking_pairs += 1
    return attacking_pairs

# Generate neighbors by swapping two queens in different rows.
def getNeighbours(state):
    neighbours = []
    for i in range(N):
        for j in range(i + 1, N):
            new_state = state[:]
            new_state[i], new_state[j] = new_state[j], new_state[i]
            neighbours.append(new_state)
    return neighbours

# Hill climbing algorithm
def hillClimbing(initial_state):
    current_state = initial_state
    current_cost = calculateCost(current_state)

    iteration = 0
    while True:
        print(f"\nIteration {iteration}")
        print(f"Current State: {current_state}, Cost: {current_cost}")

        neighbours = getNeighbours(current_state)
        next_state = current_state
        next_cost = current_cost

        # Evaluate each neighbor and print their costs
        for neighbour in neighbours:
            cost = calculateCost(neighbour)
            print(f"Neighbour: {neighbour}, Cost: {cost}")
            if cost < next_cost:
                next_state = neighbour
                next_cost = cost

        # Check if we have reached a local minimum or found a solution
        if next_cost == current_cost:
            break  # Local optimum reached
        else:
            current_state, current_cost = next_state, next_cost

        # Goal state found if no queens are attacking each other
        if current_cost == 0:
            break

        iteration += 1

    return current_state, current_cost

# Main execution
initial_state = list(map(int, input(f"Enter initial state as 4 space-separated integers (0 to {N} ): ").split()))
solution_state, solution_cost = hillClimbing(initial_state)

# Print final results
print("\nFinal Results")
print("Initial State:", initial_state)
print("Final State (Solution):", solution_state)
print("Final Cost (Attacking Pairs):", solution_cost)

if solution_cost == 0:
    print("Solution found!")
else:
    print("Local optimum reached, but no solution.")
# Out:
# Enter initial state as 4 space-separated integers (0 to 8 ): 0 2 4 5 6 7 8 1 3
#
# Iteration 0
# Current State: [0, 2, 4, 5, 6, 7, 8, 1, 3], Cost: 11
# Neighbour: [2, 0, 4, 5, 6, 7, 8, 1, 3], Cost: 16
# Neighbour: [4, 2, 0, 5, 6, 7, 8, 1, 3], Cost: 7
# Neighbour: [5, 2, 4, 0, 6, 7, 8, 1, 3], Cost: 7
# Neighbour: [6, 2, 4, 5, 0, 7, 8, 1, 3], Cost: 8
# Neighbour: [7, 2, 4, 5, 6, 0, 8, 1, 3], Cost: 7
# Neighbour: [8, 2, 4, 5, 6, 7, 0, 1, 3], Cost: 11
# Neighbour: [1, 2, 4, 5, 6, 7, 8, 0, 3], Cost: 11
# Neighbour: [0, 4, 2, 5, 6, 7, 8, 1, 3], Cost: 8
# Neighbour: [0, 5, 4, 2, 6, 7, 8, 1, 3], Cost: 7
# Neighbour: [0, 6, 4, 5, 2, 7, 8, 1, 3], Cost: 8
# Neighbour: [0, 7, 4, 5, 6, 2, 8, 1, 3], Cost: 9
# Neighbour: [0, 8, 4, 5, 6, 7, 2, 1, 3], Cost: 9
# Neighbour: [0, 1, 4, 5, 6, 7, 8, 2, 3], Cost: 11
# Neighbour: [0, 2, 5, 4, 6, 7, 8, 1, 3], Cost: 5
# Neighbour: [0, 2, 6, 5, 4, 7, 8, 1, 3], Cost: 10
# Neighbour: [0, 2, 7, 5, 6, 4, 8, 1, 3], Cost: 5
# Neighbour: [0, 2, 8, 5, 6, 7, 4, 1, 3], Cost: 7
# Neighbour: [0, 2, 1, 5, 6, 7, 8, 4, 3], Cost: 7
# Neighbour: [0, 2, 4, 6, 5, 7, 8, 1, 3], Cost: 5
# Neighbour: [0, 2, 4, 7, 6, 5, 8, 1, 3], Cost: 7
# Neighbour: [0, 2, 4, 8, 6, 7, 5, 1, 3], Cost: 4
# Neighbour: [0, 2, 4, 1, 6, 7, 8, 5, 3], Cost: 8
# Neighbour: [0, 2, 4, 5, 7, 6, 8, 1, 3], Cost: 6
# Neighbour: [0, 2, 4, 5, 8, 7, 6, 1, 3], Cost: 8
# Neighbour: [0, 2, 4, 5, 1, 7, 8, 6, 3], Cost: 6
# Neighbour: [0, 2, 4, 5, 6, 8, 7, 1, 3], Cost: 6
# Neighbour: [0, 2, 4, 5, 6, 1, 8, 7, 3], Cost: 9
# Neighbour: [0, 2, 4, 5, 6, 7, 1, 8, 3], Cost: 7
#
# Iteration 1
# Current State: [0, 2, 4, 8, 6, 7, 5, 1, 3], Cost: 4
# Neighbour: [2, 0, 4, 8, 6, 7, 5, 1, 3], Cost: 8
# Neighbour: [4, 2, 0, 8, 6, 7, 5, 1, 3], Cost: 2
# Neighbour: [8, 2, 4, 0, 6, 7, 5, 1, 3], Cost: 5
# Neighbour: [6, 2, 4, 8, 0, 7, 5, 1, 3], Cost: 3
# Neighbour: [7, 2, 4, 8, 6, 0, 5, 1, 3], Cost: 2
# Neighbour: [5, 2, 4, 8, 6, 7, 0, 1, 3], Cost: 6
# Neighbour: [1, 2, 4, 8, 6, 7, 5, 0, 3], Cost: 5
# Neighbour: [0, 4, 2, 8, 6, 7, 5, 1, 3], Cost: 3
# Neighbour: [0, 8, 4, 2, 6, 7, 5, 1, 3], Cost: 4
# Neighbour: [0, 6, 4, 8, 2, 7, 5, 1, 3], Cost: 4
# Neighbour: [0, 7, 4, 8, 6, 2, 5, 1, 3], Cost: 3
# Neighbour: [0, 5, 4, 8, 6, 7, 2, 1, 3], Cost: 5
# Neighbour: [0, 1, 4, 8, 6, 7, 5, 2, 3], Cost: 5
# Neighbour: [0, 2, 8, 4, 6, 7, 5, 1, 3], Cost: 3
# Neighbour: [0, 2, 6, 8, 4, 7, 5, 1, 3], Cost: 5
# Neighbour: [0, 2, 7, 8, 6, 4, 5, 1, 3], Cost: 4
# Neighbour: [0, 2, 5, 8, 6, 7, 4, 1, 3], Cost: 2
# Neighbour: [0, 2, 1, 8, 6, 7, 5, 4, 3], Cost: 6
# Neighbour: [0, 2, 4, 6, 8, 7, 5, 1, 3], Cost: 2
# Neighbour: [0, 2, 4, 7, 6, 8, 5, 1, 3], Cost: 2
# Neighbour: [0, 2, 4, 5, 6, 7, 8, 1, 3], Cost: 11
# Neighbour: [0, 2, 4, 1, 6, 7, 5, 8, 3], Cost: 4
# Neighbour: [0, 2, 4, 8, 7, 6, 5, 1, 3], Cost: 7
# Neighbour: [0, 2, 4, 8, 5, 7, 6, 1, 3], Cost: 4
# Neighbour: [0, 2, 4, 8, 1, 7, 5, 6, 3], Cost: 3
# Neighbour: [0, 2, 4, 8, 6, 5, 7, 1, 3], Cost: 4
# Neighbour: [0, 2, 4, 8, 6, 1, 5, 7, 3], Cost: 4
# Neighbour: [0, 2, 4, 8, 6, 7, 1, 5, 3], Cost: 4
#
# Iteration 2
# Current State: [4, 2, 0, 8, 6, 7, 5, 1, 3], Cost: 2
# Neighbour: [2, 4, 0, 8, 6, 7, 5, 1, 3], Cost: 5
# Neighbour: [0, 2, 4, 8, 6, 7, 5, 1, 3], Cost: 4
# Neighbour: [8, 2, 0, 4, 6, 7, 5, 1, 3], Cost: 3
# Neighbour: [6, 2, 0, 8, 4, 7, 5, 1, 3], Cost: 2
# Neighbour: [7, 2, 0, 8, 6, 4, 5, 1, 3], Cost: 2
# Neighbour: [5, 2, 0, 8, 6, 7, 4, 1, 3], Cost: 4
# Neighbour: [1, 2, 0, 8, 6, 7, 5, 4, 3], Cost: 5
# Neighbour: [4, 0, 2, 8, 6, 7, 5, 1, 3], Cost: 4
# Neighbour: [4, 8, 0, 2, 6, 7, 5, 1, 3], Cost: 2
# Neighbour: [4, 6, 0, 8, 2, 7, 5, 1, 3], Cost: 3
# Neighbour: [4, 7, 0, 8, 6, 2, 5, 1, 3], Cost: 2
# Neighbour: [4, 5, 0, 8, 6, 7, 2, 1, 3], Cost: 3
# Neighbour: [4, 1, 0, 8, 6, 7, 5, 2, 3], Cost: 3
# Neighbour: [4, 2, 8, 0, 6, 7, 5, 1, 3], Cost: 3
# Neighbour: [4, 2, 6, 8, 0, 7, 5, 1, 3], Cost: 4
# Neighbour: [4, 2, 7, 8, 6, 0, 5, 1, 3], Cost: 2
# Neighbour: [4, 2, 5, 8, 6, 7, 0, 1, 3], Cost: 2
# Neighbour: [4, 2, 1, 8, 6, 7, 5, 0, 3], Cost: 4
# Neighbour: [4, 2, 0, 6, 8, 7, 5, 1, 3], Cost: 2
# Neighbour: [4, 2, 0, 7, 6, 8, 5, 1, 3], Cost: 2
# Neighbour: [4, 2, 0, 5, 6, 7, 8, 1, 3], Cost: 7
# Neighbour: [4, 2, 0, 1, 6, 7, 5, 8, 3], Cost: 4
# Neighbour: [4, 2, 0, 8, 7, 6, 5, 1, 3], Cost: 7
# Neighbour: [4, 2, 0, 8, 5, 7, 6, 1, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 1, 7, 5, 6, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 6, 5, 7, 1, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 6, 1, 5, 7, 3], Cost: 1
# Neighbour: [4, 2, 0, 8, 6, 7, 1, 5, 3], Cost: 3
#
# Iteration 3
# Current State: [4, 2, 0, 8, 6, 1, 5, 7, 3], Cost: 1
# Neighbour: [2, 4, 0, 8, 6, 1, 5, 7, 3], Cost: 3
# Neighbour: [0, 2, 4, 8, 6, 1, 5, 7, 3], Cost: 4
# Neighbour: [8, 2, 0, 4, 6, 1, 5, 7, 3], Cost: 1
# Neighbour: [6, 2, 0, 8, 4, 1, 5, 7, 3], Cost: 3
# Neighbour: [1, 2, 0, 8, 6, 4, 5, 7, 3], Cost: 3
# Neighbour: [5, 2, 0, 8, 6, 1, 4, 7, 3], Cost: 3
# Neighbour: [7, 2, 0, 8, 6, 1, 5, 4, 3], Cost: 3
# Neighbour: [4, 0, 2, 8, 6, 1, 5, 7, 3], Cost: 4
# Neighbour: [4, 8, 0, 2, 6, 1, 5, 7, 3], Cost: 1
# Neighbour: [4, 6, 0, 8, 2, 1, 5, 7, 3], Cost: 4
# Neighbour: [4, 1, 0, 8, 6, 2, 5, 7, 3], Cost: 3
# Neighbour: [4, 5, 0, 8, 6, 1, 2, 7, 3], Cost: 3
# Neighbour: [4, 7, 0, 8, 6, 1, 5, 2, 3], Cost: 1
# Neighbour: [4, 2, 8, 0, 6, 1, 5, 7, 3], Cost: 2
# Neighbour: [4, 2, 6, 8, 0, 1, 5, 7, 3], Cost: 4
# Neighbour: [4, 2, 1, 8, 6, 0, 5, 7, 3], Cost: 3
# Neighbour: [4, 2, 5, 8, 6, 1, 0, 7, 3], Cost: 1
# Neighbour: [4, 2, 7, 8, 6, 1, 5, 0, 3], Cost: 2
# Neighbour: [4, 2, 0, 6, 8, 1, 5, 7, 3], Cost: 1
# Neighbour: [4, 2, 0, 1, 6, 8, 5, 7, 3], Cost: 2
# Neighbour: [4, 2, 0, 5, 6, 1, 8, 7, 3], Cost: 4
# Neighbour: [4, 2, 0, 7, 6, 1, 5, 8, 3], Cost: 3
# Neighbour: [4, 2, 0, 8, 1, 6, 5, 7, 3], Cost: 4
# Neighbour: [4, 2, 0, 8, 5, 1, 6, 7, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 7, 1, 5, 6, 3], Cost: 4
# Neighbour: [4, 2, 0, 8, 6, 5, 1, 7, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 6, 7, 5, 1, 3], Cost: 2
# Neighbour: [4, 2, 0, 8, 6, 1, 7, 5, 3], Cost: 2
#
# Final Results
# Initial State: [0, 2, 4, 5, 6, 7, 8, 1, 3]
# Final State (Solution): [4, 2, 0, 8, 6, 1, 5, 7, 3]
# Final Cost (Attacking Pairs): 1
# Local optimum reached, but no solution.
